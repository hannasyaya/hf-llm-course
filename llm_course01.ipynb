# %% [markdown]
# <a href="https://colab.research.google.com/github/hannasyaya/hf-llm-course/blob/main/llm_course01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers[sentencepiece]

# %%
from transformers import pipeline

# %%
classifier = pipeline("sentiment-analysis")
classifier(["hello everyone", "I think The Office TV Show is overrated. The jokes from actors are not funny to me"])
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# [{'label': 'POSITIVE', 'score': 0.9992765784263611},
#  {'label': 'NEGATIVE', 'score': 0.999800980091095}]

# %%
classifier = pipeline("zero-shot-classification")
classifier(
    """
    CBC News has listened to courtroom submissions in the case, which cast light on the Saanich Police Department investigation. Those records, along with victim impact statements and interviews with victims, raise questions about why police did not act to stop the voyeur sooner.
Saanich police did not answer questions from CBC News for this story, but said in a statement that the department's decisions took a trauma-informed approach to avoid "actions that could contribute to further victimization.
""",
    candidate_labels=["Eduation", "Health", "History"]
)
# Out:
# [transformers] No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 1.63GB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ...

# %%
generator = pipeline("text-generation")
generator("Temperature fall down during")
# Out:
# [transformers] No model was supplied, defaulted to HuggingFaceTB/SmolLM3-3B and revision a07cc9a.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/1.92k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.9k [00:00<?, ?B/s]
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# ...
# Loading weights:   0%|          | 0/326 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/182 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.4k [00:00<?, ?B/s]
# tokenizer.json: reconstructing file:   0%|          |  0.00B / 17.2MB
# tokenizer.json: downloading bytes:           |  0.00B
# special_tokens_map.json:   0%|          | 0.00/289 [00:00<?, ?B/s]
# ...

# %%
generator2 = pipeline("text-generation", model="HuggingFaceTB/SmolLM2-135M")
generator2("Florent and his family are traveling to paris")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1295/3885919039.py in <cell line: 0>()
# ----> 1 generator2 = pipeline("text-generation", model="HuggingFaceTB/SmolLM2-135M")
#       2 generator2("Florent and his family are traveling to paris")
#
# NameError: name 'pipeline' is not defined

# %%
unmasker = pipeline('fill-mask', model='bert-base-cased')
unmasker("The woman worked as a [MASK].")
# Out:
# Loading weights:   0%|          | 0/202 [00:00<?, ?it/s]
# [transformers] BertForMaskedLM LOAD REPORT from: bert-base-cased
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# cls.seq_relationship.weight | UNEXPECTED |  |
# bert.pooler.dense.bias      | UNEXPECTED |  |
# bert.pooler.dense.weight    | UNEXPECTED |  |
# cls.seq_relationship.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [{'score': 0.16927455365657806,
#   'token': 7439,
#   'token_str': 'nurse',
#   'sequence': 'The woman worked as a nurse.'},
#  {'score': 0.1501094549894333,
#   'token': 15098,
#   'token_str': 'waitress',
#   'sequence': 'The woman worked as a waitress.'},
#  {'score': 0.0560016855597496,
#   'token': 13487,
#   'token_str': 'maid',
#   'sequence': 'The woman worked as a maid.'},
#  {'score': 0.048388391733169556,
#   'token': 26458,
# ...

# %%
from transformers import pipeline

summarizer = pipeline("ner")
summarizer(
    """
    America has changed dramatically during recent years. Not only has the number of
    graduates in traditional engineering disciplines such as mechanical, civil,
    electrical, chemical, and aeronautical engineering declined, but in most of
    the premier American universities engineering curricula now concentrate on
    and encourage largely the study of engineering science. As a result, there
    are declining offerings in engineering subjects dealing with infrastructure,
    the environment, and related issues, and greater concentration on high
    technology subjects, largely supporting increasingly complex scientific
    developments. While the latter is important, it should not be at the expense
    of more traditional engineering.

    Rapidly developing economies such as China and India, as well as other
    industrial countries in Europe and Asia, continue to encourage and advance
    the teaching of engineering. Both China and India, respectively, graduate
    six and eight times as many traditional engineers as does the United States.
    Other industrial countries at minimum maintain their output, while America
    suffers an increasingly serious decline in the number of engineering graduates
    and a lack of well-educated engineers.
"""
)
# Out:
# [transformers] No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# [transformers] BertForTokenClassification LOAD REPORT from: dbmdz/bert-large-cased-finetuned-conll03-english
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.bias   | UNEXPECTED |  |
# bert.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [{'entity': 'I-LOC',
#   'score': np.float32(0.9993754),
#   'index': 1,
#   'word': 'America',
#   'start': 5,
#   'end': 12},
#  {'entity': 'I-MISC',
#   'score': np.float32(0.9994704),
#   'index': 44,
#   'word': 'American',
#   'start': 265,
#   'end': 273},
#  {'entity': 'I-LOC',
# ...
